# %% [markdown]
# <h1 style="font-family: 'Georgia', serif; text-align: center; font-weight: normal; margin-bottom: 0px;">
#   <em>Coding a Dense Class</em>
# </h1>
# <p style="text-align: center; font-family: 'Georgia', serif; color: gray; margin-top: 5px;">
#   Object-Oriented Network Architecture
# </p>
# <hr style="width: 50%; border: 1px solid #ddd;">

# %% [markdown]
# <center>
#     <img src="Note-Images/Implementing-Dense-Layer-Class.jpg">
# </center>

# %%
pip install nnfs

# %%
import numpy as np
import nnfs
from nnfs.datasets import spiral_data

# %%
X,y = spiral_data(samples = 100, classes =3)

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:,0], X[:,1], c = y, cmap = 'brg') # X[:,0] is x coordinate of the point and the other one is y coordinate
plt.show()

# %%
class Dense_Layer:

    def __init__(self, n_inputs, n_neurons):
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
        self.biases = np.zeros((1, n_neurons))

    def forward_pass(self, X):
        self.output = np.dot(X, self.weights) + self.biases
        return self.output

Layer1 = Dense_Layer(2,8)

Y = Layer1.forward_pass(X)

print(Y[5, :])
# Out:
# [ 3.64903765e-05  3.15444339e-04  5.96449376e-04 -7.58991570e-05
#   1.64155064e-04  6.08209684e-04  5.67072098e-04 -9.18086018e-04]
