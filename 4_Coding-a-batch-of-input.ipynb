# %% [markdown]
# <h1 style="font-family: 'Georgia', serif; text-align: center; font-weight: normal; margin-bottom: 0px;">
#   <em>Coding an Input Batch</em>
# </h1>
# <p style="text-align: center; font-family: 'Georgia', serif; color: gray; margin-top: 5px;">
#   Matrix Dimensions & Parallel Processing
# </p>
# <hr style="width: 50%; border: 1px solid #ddd;">

# %% [markdown]
# <center>
#     <img src="Note-Images/Batch.jpg">
# </center>

# %%
import numpy as np

# %%
X = [[1,2,3],
    [5,6,7]] #input
W = [[0.1, 0.3, 0.2],
     [0.4, 0.2, 0.1],
     [0.01, -0.3, -0.6]] #Weights
b = [0.01, -0.03, 0.15] #bias

#Converting to matrix
X = np.array((X))
W = np.array((W)) 

Y = np.dot(X, W.T) + b

print(Y)
# Out:
# [[ 1.31  1.07 -2.24]
#  [ 3.71  3.87 -5.8 ]]
